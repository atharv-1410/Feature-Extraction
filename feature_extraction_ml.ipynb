# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#checking image shape
image = imread('/content/drive/MyDrive/STC/truck254.jpeg')
image.shape, imshow(image)
image.shape, image
# Out:
# ((188, 268, 3),
#  array([[[ 91, 113, 173],
#          [ 91, 113, 173],
#          [ 91, 113, 173],
#          ...,
#          [ 82, 106, 168],
#          [ 82, 106, 168],
#          [ 82, 106, 168]],
#
#         [[ 92, 114, 174],
#          [ 92, 114, 174],
#          [ 92, 114, 174],
#          ...,
#          [ 83, 107, 169],
#          [ 83, 107, 169],
#          [ 83, 107, 169]],
#
#         [[ 93, 115, 175],
#          [ 93, 115, 175],
#          [ 93, 115, 175],
#          ...,
#          [ 84, 108, 170],
#          [ 84, 108, 170],
#          [ 84, 108, 170]],
#
#         ...,
#
#         [[119, 106,  90],
#          [119, 106,  90],
#          [119, 106,  90],
#          ...,
#          [ 84,  85,  80],
#          [ 83,  84,  79],
#          [ 83,  84,  79]],
#
#         [[119, 106,  90],
#          [119, 106,  90],
#          [119, 106,  90],
#          ...,
#          [ 83,  84,  79],
#          [ 83,  84,  79],
#          [ 82,  83,  78]],
#
#         [[119, 106,  90],
# ...

# %%
image.shape, image
# Out:
# ((188, 268, 3),
#  array([[[ 91, 113, 173],
#          [ 91, 113, 173],
#          [ 91, 113, 173],
#          ...,
#          [ 82, 106, 168],
#          [ 82, 106, 168],
#          [ 82, 106, 168]],
#
#         [[ 92, 114, 174],
#          [ 92, 114, 174],
#          [ 92, 114, 174],
#          ...,
#          [ 83, 107, 169],
#          [ 83, 107, 169],
#          [ 83, 107, 169]],
#
#         [[ 93, 115, 175],
#          [ 93, 115, 175],
#          [ 93, 115, 175],
#          ...,
#          [ 84, 108, 170],
#          [ 84, 108, 170],
#          [ 84, 108, 170]],
#
#         ...,
#
#         [[119, 106,  90],
#          [119, 106,  90],
#          [119, 106,  90],
#          ...,
#          [ 84,  85,  80],
#          [ 83,  84,  79],
#          [ 83,  84,  79]],
#
#         [[119, 106,  90],
#          [119, 106,  90],
#          [119, 106,  90],
#          ...,
#          [ 83,  84,  79],
#          [ 83,  84,  79],
#          [ 82,  83,  78]],
#
#         [[119, 106,  90],
# ...

# %%
#pixel features

features = np.resize(image, (188*268))

features.shape, features
# Out:
# ((50384,), array([ 91, 113, 173, ...,  95,  74,  80], dtype=uint8))

# %% [markdown]
# Importing image with cv2

# %%
import cv2

# %%
print(image)
# Out:
# [[[ 91 113 173]
#   [ 91 113 173]
#   [ 91 113 173]
#   ...
#   [ 82 106 168]
#   [ 82 106 168]
#   [ 82 106 168]]
#
#  [[ 92 114 174]
#   [ 92 114 174]
#   [ 92 114 174]
#   ...
#   [ 83 107 169]
#   [ 83 107 169]
#   [ 83 107 169]]
#
#  [[ 93 115 175]
#   [ 93 115 175]
#   [ 93 115 175]
#   ...
#   [ 84 108 170]
#   [ 84 108 170]
#   [ 84 108 170]]
#
#  ...
#
#  [[119 106  90]
#   [119 106  90]
#   [119 106  90]
#   ...
#   [ 84  85  80]
#   [ 83  84  79]
#   [ 83  84  79]]
#
#  [[119 106  90]
#   [119 106  90]
#   [119 106  90]
#   ...
#   [ 83  84  79]
#   [ 83  84  79]
#   [ 82  83  78]]
#
#  [[119 106  90]
#   [119 106  90]
#   [119 106  90]
#   ...
#   [ 82  83  78]
#   [ 82  83  78]
#   [ 81  82  77]]]

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_rgb.shape
# Out:
# (188, 268, 3)

# %%
print(image_rgb)
# Out:
# [[[173 113  91]
#   [173 113  91]
#   [173 113  91]
#   ...
#   [168 106  82]
#   [168 106  82]
#   [168 106  82]]
#
#  [[174 114  92]
#   [174 114  92]
#   [174 114  92]
#   ...
#   [169 107  83]
#   [169 107  83]
#   [169 107  83]]
#
#  [[175 115  93]
#   [175 115  93]
#   [175 115  93]
#   ...
#   [170 108  84]
#   [170 108  84]
#   [170 108  84]]
#
#  ...
#
#  [[ 90 106 119]
#   [ 90 106 119]
#   [ 90 106 119]
#   ...
#   [ 80  85  84]
#   [ 79  84  83]
#   [ 79  84  83]]
#
#  [[ 90 106 119]
#   [ 90 106 119]
#   [ 90 106 119]
#   ...
#   [ 79  84  83]
#   [ 79  84  83]
#   [ 78  83  82]]
#
#  [[ 90 106 119]
#   [ 90 106 119]
#   [ 90 106 119]
#   ...
#   [ 78  83  82]
#   [ 78  83  82]
#   [ 77  82  81]]]

# %%
#pixel features

features = np.resize(image_rgb, (188*268))

features.shape
# Out:
# (50384,)

# %%
features
# Out:
# array([173, 113,  91, ...,  73,  96,  80], dtype=uint8)

# %%
image = imread('/content/drive/MyDrive/STC/truck254.jpeg')
feature_matrix = np.zeros((188,268))
feature_matrix.shape
# Out:
# (188, 268)

# %%
for i in range(0, 188):
    for j in range(0, 268):
        feature_matrix[i][j] = ((int(image[i, j, 0]) + int(image[i, j, 1]) + int(image[i, j, 2])) / 3)

# %%
feature_matrix
# Out:
# array([[125.66666667, 125.66666667, 125.66666667, ..., 118.66666667,
#         118.66666667, 118.66666667],
#        [126.66666667, 126.66666667, 126.66666667, ..., 119.66666667,
#         119.66666667, 119.66666667],
#        [127.66666667, 127.66666667, 127.66666667, ..., 120.66666667,
#         120.66666667, 120.66666667],
#        ...,
#        [105.        , 105.        , 105.        , ...,  83.        ,
#          82.        ,  82.        ],
#        [105.        , 105.        , 105.        , ...,  82.        ,
#          82.        ,  81.        ],
#        [105.        , 105.        , 105.        , ...,  81.        ,
#          81.        ,  80.        ]])

# %%
#Vertical edges using prewitt
import numpy as np
from skimage.io import imread, imshow
from skimage.filters import prewitt_h,prewitt_v
import matplotlib.pyplot as plt
# %matplotlib inline

#reading the image
image = imread('/content/drive/MyDrive/STC/truck254.jpeg',as_gray=True)

#calculating horizontal edges using prewitt kernel
#edges_prewitt_horizontal = prewitt_h(image)
#calculating vertical edges using prewitt kernel
edges_prewitt_vertical = prewitt_v(image)

imshow(edges_prewitt_vertical, cmap='gray')

# %%
#Horizontal edges using prewitt
import numpy as np
from skimage.io import imread, imshow
from skimage.filters import prewitt_h,prewitt_v
import matplotlib.pyplot as plt
# %matplotlib inline

#reading the image
image = imread('/content/drive/MyDrive/STC/truck254.jpeg',as_gray=True)

#calculating horizontal edges using prewitt kernel
edges_prewitt_horizontal = prewitt_h(image)
#calculating vertical edges using prewitt kernel
#edges_prewitt_vertical = prewitt_v(image)

imshow(edges_prewitt_horizontal, cmap='gray')

# %%
# !pip install rembg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 13.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.1 MB/s eta 0:00:00
# ...

# %%
#background removal
from rembg import remove
import cv2
from PIL import Image

input_path = '/content/drive/MyDrive/STC/truck254.jpeg'
output_path = '/content/drive/MyDrive/STC/output_truck254.png'

input_image = cv2.imread(input_path)
input_image_rgb = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)
output_image = remove(input_image_rgb)
output_pil_image = Image.fromarray(output_image)
output_pil_image.save(output_path)
# Out:
# ...
# 100%|███████████████████████████████████████| 176M/176M [00:00<00:00, 63.6GB/s]

# %%
image = imread("/content/drive/MyDrive/STC/truck254.jpeg")
imshow(image)

# %%
image = imread("/content/drive/MyDrive/STC/output_truck254.png")
imshow(image)

# %%
#Histogram
import cv2
import matplotlib.pyplot as plt

# Read the image
image_path = '/content/drive/MyDrive/STC/truck254.jpeg'
image = cv2.imread(image_path)

# Convert image to RGB (OpenCV uses BGR by default)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Plot the original image
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.imshow(image_rgb)
plt.title('Original Image')

# Plot the histograms
plt.subplot(1, 3, 2)
plt.hist(image_rgb[:,:,0].ravel(), bins=256, color='red', alpha=0.5, label='Red', range=(0, 256))
plt.hist(image_rgb[:,:,1].ravel(), bins=256, color='green', alpha=0.5, label='Green', range=(0, 256))
plt.hist(image_rgb[:,:,2].ravel(), bins=256, color='blue', alpha=0.5, label='Blue', range=(0, 256))

plt.title('Color Histograms')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.legend()



plt.tight_layout()
plt.show()
